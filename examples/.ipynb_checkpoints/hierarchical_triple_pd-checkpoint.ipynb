# %% [markdown]
# [IPython Notebook](hierarchicial_triple_pd.ipynb) |  [Python Script](hierarchical_triple_pd.py)

# %% [markdown]
# Hierarchical Triple (PHOEBE 2 vs Photodynam)
# ============================
#
# **NOTE**: Photodynam is an alternate backend and is not installed with PHOEBE 2.0.  In order to run this backend, you'll need to have [photodynam](https://github.com/dfm/photodynam) installed.
#
# Setup
# -----------------------------

# %% [markdown]
# As always, let's do imports and initialize a logger and a new bundle.  See [Building a System](../tutorials/building_a_system.html) for more details.

# %%
# %matplotlib inline

# %%
import phoebe
from phoebe import u # units
import numpy as np
import matplotlib.pyplot as plt

logger = phoebe.logger()

b = phoebe.default_triple()
b['q@inner'] = 0.7
b['q@outer'] = 0.6
# Out:
# WARNING: Constant u'Gravitational constant' is already has a definition in the u'si' system [astropy.constants.constant]
# WARNING:astropy:Constant u'Gravitational constant' is already has a definition in the u'si' system
# WARNING: Constant u'Solar mass' is already has a definition in the u'si' system [astropy.constants.constant]
# WARNING:astropy:Constant u'Solar mass' is already has a definition in the u'si' system
# WARNING: Constant u'Solar radius' is already has a definition in the u'si' system [astropy.constants.constant]
# WARNING:astropy:Constant u'Solar radius' is already has a definition in the u'si' system
# WARNING: Constant u'Solar luminosity' is already has a definition in the u'si' system [astropy.constants.constant]
# WARNING:astropy:Constant u'Solar luminosity' is already has a definition in the u'si' system
# WARNING: developer mode enabled, to disable 'rm ~/.phoebe_devel_enabled' and restart phoebe
# /usr/local/lib/python2.7/dist-packages/astropy/units/quantity.py:732: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   return super(Quantity, self).__eq__(other)

# %%
b.add_dataset('lc', times=np.linspace(0,10,201), dataset='lc01')
# Out:
# <ParameterSet: 14 parameters | kinds: lc, lc_dep>

# %%
b.add_dataset('rv', times=np.linspace(0,10,201), dataset='rv01')
# Out:
# <ParameterSet: 14 parameters | kinds: rv, rv_dep>

# %%
b.add_dataset('orb', times=np.linspace(0,10,201), dataset='orb01')
# Out:
# <ParameterSet: 3 parameters | components: starA, starC, starB>

# %%
b.set_value_all('ld_func', 'logarithmic')
b.set_value_all('ld_coeffs', [0, 0])

# %% [markdown]
# Running Compute
# -----------------------

# %% [markdown]
# Photodynam includes ltte effects by default, so let's enable them in PHOEBE 2 as well.

# %%
b.add_compute(compute='phoebe', ltte=True, rv_method='dynamical', atm='blackbody', reflection_method='none')
# Out:
# <ParameterSet: 32 parameters | datasets: lc01, orb01, rv01>

# %%
b.add_compute('photodynam', compute='pd')
# Out:
# <ParameterSet: 5 parameters | datasets: lc01, orb01, rv01>

# %%
b.run_compute(compute='phoebe', model='phoebemodel')
# Out:
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# ...
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDims: use PyArray_SimpleNew.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/backend/eclipse.py:14: DeprecationWarning: PyArray_FromDimsAndDataAndDescr: use PyArray_NewFromDescr.
#   hull, inside = ceclipse.graham_scan_inside_hull(front[sa], back)
# <ParameterSet: 29 parameters | kinds: rv, orb, lc>

# %%
b.set_value_all('pbscale', 'pblum')
# TODO: remove this once photodynam supports coupled pblums
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f7fd82638bb2> in <module>()
# ----> 1 b.set_value_all('pbscale', 'pblum')
#       2 # TODO: remove this once photodynam supports coupled pblums
#
# /home/kyle/.local/lib/python2.7/site-packages/phoebe/parameters/parameters.pyc in set_value_all(self, twig, value, check_default, **kwargs)
#    1683
#    1684         if not kwargs.pop('ignore_none', False) and not len(params):
# -> 1685             raise ValueError("no parameters found")
#    1686
#    1687         for param in params:
#
# ValueError: no parameters found

# %%
b.run_compute(compute='pd', model='pdmodel')

# %% [markdown]
# Plotting
# -------------------------

# %%
axs, artists = b['lc01@phoebemodel'].plot()
axs, artists = b['lc01@pdmodel'].plot()

# %% [markdown]
# Since RV and orbit plots contain lines for multiple stars, we'll compare PHOEBE 2.0 (left) vs Photodynam (right) side-by-side.

# %%
fig = plt.figure(figsize=(10,6))
ax1, ax2 = fig.add_subplot(121), fig.add_subplot(122)

axs, artists = b['rv01@phoebemodel'].plot(ax=ax1)
axs, artists = b['rv01@pdmodel'].plot(ax=ax2)

# %%
fig = plt.figure(figsize=(10,6))
ax1, ax2 = fig.add_subplot(121), fig.add_subplot(122)

axs, artists = b['orb01@phoebemodel'].plot(x='xs', y='zs', ax=ax1)
axs, artists = b['orb01@pdmodel'].plot(x='xs', y='zs', ax=ax2)

# %%
fig = plt.figure(figsize=(10,6))
ax1, ax2 = fig.add_subplot(121), fig.add_subplot(122)

axs, artists = b['orb01@phoebemodel'].plot(x='times', y='vzs', ax=ax1)
axs, artists = b['orb01@pdmodel'].plot(x='times', y='vzs', ax=ax2)
