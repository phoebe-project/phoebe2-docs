# %% [markdown]
# Surface Gravity (logg)
# ============================
#
# Setup
# -----------------------------

# %% [markdown]
# Let's first make sure we have the latest version of PHOEBE 2.3 installed (uncomment this line if running in an online notebook session such as colab).

# %%
#!pip install -I "phoebe>=2.3,<2.4"

# %% [markdown]
# As always, let's do imports and initialize a logger and a new Bundle.

# %%
import phoebe
from phoebe import u # units
import numpy as np
import matplotlib.pyplot as plt

logger = phoebe.logger()

b = phoebe.default_binary()

# %% [markdown]
# Relevant Parameters
# ------------------------
#
# The 'logg' parameter defines the stellar surface gravity **at requiv** and is constrained by default.
#
# **IMPORTANT NOTE**: as the `logg` parameter is defined to be the surface gravity given the value of `mass` and `requiv`, it may not be appropriate to compare or fix the value from an "observed" value of logg (from a spectrum, for example).

# %%
print(b.filter('logg', context='component'))
# Out:
# ParameterSet: 2 parameters
# C          logg@primary@component: 4.437551877570185
# C        logg@secondary@component: 4.437551877570185

# %%
print(b.filter('logg', context='constraint'))
# Out:
# ParameterSet: 2 parameters
#           logg@primary@constraint: log10((({mass@primary@component} / ({requiv@primary@component} ** 2.000000)) * 2942.206218) * 9.319541)
#         logg@secondary@constraint: log10((({mass@secondary@component} / ({requiv@secondary@component} ** 2.000000)) * 2942.206218) * 9.319541)

# %% [markdown]
# Flipping the Constraint
# -----------------------------------

# %% [markdown]
# The `logg` constraint can be easily flipped so that `logg` is provided by the user in place of `requiv`.
#
# See also:
#  * [tutorial on constraints](./constraints.ipynb)
#  * [flip_constraint API docs](../api/phoebe.frontend.bundle.Bundle.flip_constraint.md)

# %%
print(b.filter(qualifier=['logg', 'mass', 'requiv'], component='primary'))
# Out:
# ParameterSet: 5 parameters
#          requiv@primary@component: 1.0 solRad
# C          logg@primary@component: 4.437551877570185
# C          mass@primary@component: 0.9988131358058301 solMass
#           logg@primary@constraint: log10((({mass@primary@component} / ({requiv@primary@component} ** 2.000000)) * 2942.206218) * 9.319541)
#           mass@primary@constraint: (39.478418 * ({sma@binary@component} ** 3.000000)) / ((({period@binary@component} ** 2.000000) * (1.000000 + {q@binary@component})) * 2942.206217504419328179210424423218)

# %%
b.flip_constraint('logg@primary', solve_for='requiv')
# Out:
# <ConstraintParameter: {requiv@primary@component} = sqrt((({mass@primary@component} * 2942.206218) * 9.319541) / (10.000000 ** {logg@primary@component})) (solar units) => 1.0000000000000004 solRad>

# %%
print(b.filter(qualifier=['logg', 'mass', 'requiv'], component='primary'))
# Out:
# ParameterSet: 5 parameters
# C        requiv@primary@component: 1.0000000000000004 solRad
#            logg@primary@component: 4.437551877570185
# C          mass@primary@component: 0.9988131358058301 solMass
#                 requiv@constraint: sqrt((({mass@primary@component} * 2942.206218) * 9.319541) / (10.000000 ** {logg@primary@component}))
#           mass@primary@constraint: (39.478418 * ({sma@binary@component} ** 3.000000)) / ((({period@binary@component} ** 2.000000) * (1.000000 + {q@binary@component})) * 2942.206217504419328179210424423218)

# %% [markdown]
# Flipping `logg` to solve for the `mass` is a little more involved, as `mass` is already constrained by `period`, `sma` and `q`.  So we must first flip the `mass` constraint to solve for either `period` or `sma`.

# %%
print(b.filter(qualifier=['logg', 'mass', 'requiv'], component='secondary'))
# Out:
# ParameterSet: 5 parameters
#        requiv@secondary@component: 1.0 solRad
# C        logg@secondary@component: 4.437551877570185
# C        mass@secondary@component: 0.9988131358058301 solMass
#                   logg@constraint: log10((({mass@secondary@component} / ({requiv@secondary@component} ** 2.000000)) * 2942.206218) * 9.319541)
#         mass@secondary@constraint: (39.478418 * ({sma@binary@component} ** 3.000000)) / ((({period@binary@component} ** 2.000000) * (1.000000 + (1.000000 / {q@binary@component}))) * 2942.206217504419328179210424423218)

# %%
b.flip_constraint('mass@secondary', solve_for='sma')
# Out:
# <ConstraintParameter: {sma@binary@component} = (((({mass@secondary@component} * ({period@binary@component} ** 2.000000)) * (1.000000 + (1.000000 / {q@binary@component}))) * 2942.206217504419328179210424423218) / 39.478418) ** (1./3) (solar units) => 5.299999999999999 solRad>

# %%
print(b.filter(qualifier=['logg', 'mass', 'requiv'], component='secondary'))
# Out:
# ParameterSet: 4 parameters
#        requiv@secondary@component: 1.0 solRad
# C        logg@secondary@component: 4.437551877570185
#          mass@secondary@component: 0.9988131358058301 solMass
#                   logg@constraint: log10((({mass@secondary@component} / ({requiv@secondary@component} ** 2.000000)) * 2942.206218) * 9.319541)

# %%
b.flip_constraint('logg@secondary', solve_for='mass')
# Out:
# <ConstraintParameter: {mass@secondary@component} = (({requiv@secondary@component} ** 2.000000) * (10.000000 ** {logg@secondary@component})) / 27420.011166 (solar units) => 0.9988131472111608 solMass>

# %%
print(b.filter(qualifier=['logg', 'mass', 'requiv'], component='secondary'))
# Out:
# ParameterSet: 4 parameters
#        requiv@secondary@component: 1.0 solRad
#          logg@secondary@component: 4.437551877570185
# C        mass@secondary@component: 0.9988131472111608 solMass
#         mass@secondary@constraint: (({requiv@secondary@component} ** 2.000000) * (10.000000 ** {logg@secondary@component})) / 27420.011166

# %% [markdown]
# Input vs Observed
# ---------------------------------------

# %% [markdown]
# As mentioned above, the `logg` parameter is defined explicitly to be at `requiv` and may not be comparable directly to an estimation of logg from observations.
#
# To show this, we'll see that it can even differ from the flux-weighted loggs of the individual surface elements.

# %%
b.add_dataset('lc', dataset='lc01')
b.add_dataset('mesh', times=[0, 0.25], columns=['loggs', 'areas', 'mus', 'visibilities', 'abs_intensities@lc01', 'ldint@lc01'])
# Out:
# Thu, 17 Sep 2020 11:06 BUNDLE       WARNING mesh dataset uses 'compute_times' instead of 'times', applying value sent as 'times' to 'compute_times'.
# <ParameterSet: 83 parameters | contexts: constraint, compute, figure, dataset>

# %%
b.run_compute(irrad_method='none')
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 29.32it/s]
# <ParameterSet: 43 parameters | datasets: lc01, mesh01>

# %% [markdown]
# Just by plotting the mesh at two different times/phases, we can already imagine that an "observed" logg could be time-dependent.

# %%
out = b['primary@mesh'].plot(time=0.0, fc='loggs', show=True, draw_sidebars=True)

# %%
out = b['primary@mesh'].plot(time=0.25, fc='loggs', show=True, draw_sidebars=True)

# %% [markdown]
# Now we can manually compute the 'flux-weighted' logg from each of these times (similar to the way that RVs are computed to account for Rossiter-McLaughlin, but note that even flux-weighted loggs may not be a fair comparison to spectral-derived loggs).

# %%
for time in [0.0, 0.25]:
    ps = b.filter(time=time, component='primary', context='model')
    fluxes = ps.get_value('abs_intensities') * ps.get_value('areas') * ps.get_value('mus') * ps.get_value('ldint') * ps.get_value('visibilities')
    visible = ps.get_value('visibilities') > 0
    logg = np.average(ps.get_value('loggs')[visible], weights=fluxes[visible])
    print("time = {}, logg weighted = {}".format(time, logg))
# Out:
# time = 0.0, logg weighted = 4.440828508298275
# time = 0.25, logg weighted = 4.434277398283176

# %%
print("logg parameter value = {}".format(b.get_value('logg', component='primary')))
# Out:
# logg parameter value = 4.437551877570185
