# %% [markdown]
# Comparing Contacts Binaries in PHOEBE 2 vs PHOEBE Legacy
# ============================
#
# **NOTE**: PHOEBE 1.0 legacy is an alternate backend and is not installed with PHOEBE 2.  In order to run this backend, you'll need to have [PHOEBE 1.0](https://phoebe-project.org/1.0) installed and manually install the python wrappers in the `phoebe-py` directory.
#
# Setup
# -----------------------------

# %% [markdown]
# Let's first make sure we have the latest version of PHOEBE 2.4 installed (uncomment this line if running in an online notebook session such as colab).

# %%
#!pip install -I "phoebe>=2.4,<2.5"

# %% [markdown]
# As always, let's do imports and initialize a logger and a new bundle.

# %%
import phoebe
from phoebe import u
import numpy as np
import matplotlib.pyplot as plt

logger = phoebe.logger()

b = phoebe.default_binary(contact_binary=True)
b['q'] = 0.7

# %% [markdown]
# Adding Datasets and Compute Options
# --------------------

# %%
b.add_dataset('lc', times=np.linspace(0,1,101), dataset='lc01')
b.add_dataset('rv', times=np.linspace(0,1,101), dataset='rv01')
# Out:
# <ParameterSet: 76 parameters | contexts: dataset, compute, constraint, figure>

# %% [markdown]
# Now we add compute options for the 'legacy' backend.

# %%
b.add_compute('legacy')
# Out:
# <ParameterSet: 31 parameters | datasets: _default, rv01, lc01>

# %% [markdown]
# Let's use the external atmospheres available for both phoebe1 and phoebe2

# %%
b.set_value_all('atm', 'extern_planckint')
# Out:
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.

# %% [markdown]
# Set value of gridsize for the trapezoidal (WD) mesh.

# %%
b.set_value_all('gridsize', 30)

# %% [markdown]
# Let's also disable other special effect such as heating, gravity, and light-time effects.

# %%
b.set_value_all('ld_mode', 'manual')
b.set_value_all('ld_func', 'logarithmic')
b.set_value_all('ld_coeffs', [0.0, 0.0])

b.set_value_all('rv_grav', False)
b.set_value_all('ltte', False)
# Out:
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Thu, 17 Sep 2020 18:05 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.

# %% [markdown]
# Finally, let's compute our models

# %%
b.run_compute(kind='phoebe', model='phoebe2model', irrad_method='none')
# Out:
# 100%|██████████| 101/101 [00:03<00:00, 30.61it/s]
# <ParameterSet: 7 parameters | kinds: lc, rv>

# %%
b.run_compute(kind='legacy', model='phoebe1model', irrad_method='none')
# Out:
# Thu, 17 Sep 2020 18:05 IO           WARNING requiv_max@primary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING requiv_min@primary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING logg@primary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING freq@primary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING irrad_frac_lost_bol@primary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ld_mode_bol@primary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ld_func_bol@primary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ld_coeffs_source_bol@primary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING mass@primary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING asini@primary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING requiv_max@secondary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING requiv_min@secondary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING logg@secondary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING freq@secondary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING irrad_frac_lost_bol@secondary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ld_mode_bol@secondary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ld_func_bol@secondary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ld_coeffs_source_bol@secondary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING mass@secondary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING asini@secondary@star@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING intens_weighting@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING compute_times@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING compute_phases@binary@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING phases_t0@binary@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING mask_enabled@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING mask_phases@binary@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING solver_times@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING sigmas_lnf@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING pblum_mode@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING pblum_component@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING pblum_dataset@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING pbflux@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING Finite integration Time is not fully supported and will be turned off by legacy wrapper before computation
# Thu, 17 Sep 2020 18:05 IO           WARNING fti_method@lc01@phoebe01@phoebe@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING fti_oversample@lc01@phoebe01@phoebe@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ld_mode@primary@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ld_mode@secondary@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ld_coeffs_source@primary@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ld_coeffs_source@secondary@lc01@lc@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING fti_method@lc01@legacy01@legacy@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING fti_oversample@lc01@legacy01@legacy@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING compute_times@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING mask_enabled@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING solver_times@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING intens_weighting@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING rv_method@primary@rv01@phoebe01@phoebe@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING rv_grav@primary@rv01@phoebe01@phoebe@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING sigmas_lnf@primary@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING rv_offset@primary@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ld_mode@primary@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ld_coeffs_source@primary@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING rv_method@primary@rv01@legacy01@legacy@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING compute_times@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING mask_enabled@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING solver_times@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING intens_weighting@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING rv_method@secondary@rv01@phoebe01@phoebe@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING rv_grav@secondary@rv01@phoebe01@phoebe@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING sigmas_lnf@secondary@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING rv_offset@secondary@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ld_mode@secondary@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ld_coeffs_source@secondary@rv01@rv@dataset has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING rv_method@secondary@rv01@legacy01@legacy@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING freq@binary@orbit@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING t0_perpass@binary@orbit@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING t0_supconj@binary@orbit@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING mean_anom@binary@orbit@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING long_an@binary@orbit@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING asini@binary@orbit@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ecosw@binary@orbit@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING esinw@binary@orbit@component has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING sample_from@legacy01@legacy@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING comments@legacy01@legacy@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING pblum_method@legacy01@legacy@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING irrad_method@legacy01@legacy@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING distortion_method@primary@legacy01@legacy@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING distortion_method@secondary@legacy01@legacy@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING rv_method@primary@rv01@legacy01@legacy@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING rv_method@secondary@rv01@legacy01@legacy@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING fti_method@lc01@legacy01@legacy@compute has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING t0@system has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ra@system has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING dec@system has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING distance@system has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING ebv@system has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING Av@system has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING Rv@system has no phoebe 1 corollary
# Thu, 17 Sep 2020 18:05 IO           WARNING hierarchy@system has no phoebe 1 corollary
# 100%|██████████| 3/3 [00:00<00:00, 19.85it/s]
# <ParameterSet: 7 parameters | kinds: lc, rv>

# %% [markdown]
# Plotting
# -------------------------

# %% [markdown]
# ### Light Curve

# %%
afig, mplfig = b.filter(dataset='lc01').plot(c={'phoebe2model': 'g', 'phoebe1model': 'r'}, linestyle='solid', 
                                             legend=True, show=True)

# %% [markdown]
# Now let's plot the residuals between these two models

# %%
artist, = plt.plot(b.get_value('fluxes@lc01@phoebe2model') - b.get_value('fluxes@lc01@phoebe1model'), 'g-')
artist = plt.axhline(0.0, linestyle='dashed', color='k')

# %% [markdown]
# ### RVs

# %%
afig, mplfig = b['rv01'].plot(c={'phoebe2model': 'g', 'phoebe1model': 'r'}, linestyle='solid', 
                              legend=True, show=True)

# %%
artist, = plt.plot(b.get_value('rvs@primary@phoebe2model', ) - b.get_value('rvs@primary@phoebe1model'), color='g', ls=':')
artist, = plt.plot(b.get_value('rvs@secondary@phoebe2model') - b.get_value('rvs@secondary@phoebe1model'), color='g', ls='-.')
artist = plt.axhline(0.0, linestyle='dashed', color='k')
ylim = plt.ylim(-0.3, 0.3)
