# %% [markdown]
# Comparing Contacts Binaries in PHOEBE 2 vs PHOEBE Legacy
# ============================
#
# **NOTE**: PHOEBE 1.0 legacy is an alternate backend and is not installed with PHOEBE 2.  In order to run this backend, you'll need to have [PHOEBE 1.0](https://phoebe-project.org/1.0) installed and manually install the python wrappers in the `phoebe-py` directory.
#
# Setup
# -----------------------------

# %% [markdown]
# Let's first make sure we have the latest version of PHOEBE 2.2 installed. (You can comment out this line if you don't use pip for your installation or don't want to update to the latest release).

# %%
# !pip install -I "phoebe>=2.2,<2.3"

# %% [markdown]
# As always, let's do imports and initialize a logger and a new bundle.  See [Building a System](../tutorials/building_a_system.ipynb) for more details.

# %%
# %matplotlib inline

# %%
import phoebe
from phoebe import u
import numpy as np
import matplotlib.pyplot as plt

logger = phoebe.logger()

b = phoebe.default_binary(contact_binary=True)
b['q'] = 0.7

# %% [markdown]
# Adding Datasets and Compute Options
# --------------------

# %%
b.add_dataset('lc', times=np.linspace(0,1,101), dataset='lc01')
b.add_dataset('rv', times=np.linspace(0,1,101), dataset='rv01')
# Out:
# <ParameterSet: 39 parameters | contexts: dataset, compute, constraint, figure>

# %% [markdown]
# Now we add compute options for the 'legacy' backend.

# %%
b.add_compute('legacy')
# Out:
# <ParameterSet: 19 parameters | datasets: _default, lc01, rv01>

# %% [markdown]
# Let's use the external atmospheres available for both phoebe1 and phoebe2

# %%
b.set_value_all('atm', 'extern_planckint')
# Out:
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@lc01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@lc01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@lc01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@lc01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@lc01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@lc01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.

# %% [markdown]
# Set value of gridsize for the trapezoidal (WD) mesh.

# %%
b.set_value_all('gridsize', 30)

# %% [markdown]
# Let's also disable other special effect such as heating, gravity, and light-time effects.

# %%
b.set_value_all('ld_mode', 'manual')
b.set_value_all('ld_func', 'logarithmic')
b.set_value_all('ld_coeffs', [0.0, 0.0])

b.set_value_all('rv_grav', False)
b.set_value_all('ltte', False)
# Out:
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@lc01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@lc01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@lc01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@primary@phoebe01 or ld_mode@primary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@primary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by atm='extern_planckint'.  Either change atm@secondary@phoebe01 or ld_mode@secondary@rv01.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING ld_mode='interp' not supported by 'legacy' backend used by compute='legacy01'.  Change ld_mode@secondary@rv01 or use a backend that supports atm='ck2004'.  If not addressed, this warning will continue to be raised and will throw an error at run_compute.

# %% [markdown]
# Finally, let's compute our models

# %%
b.run_compute(kind='phoebe', model='phoebe2model', irrad_method='none')
# Out:
# <ParameterSet: 8 parameters | contexts: model, figure>

# %%
b.run_compute(kind='legacy', model='phoebe1model', irrad_method='none')
# Out:
# Wed, 11 Dec 2019 14:20 BUNDLE       WARNING legacy does not natively support interpolating ld coefficients.  These will be interpolated by PHOEBE 2 and then passed to legacy.
# Wed, 11 Dec 2019 14:20 IO           WARNING requiv_max@primary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING requiv_min@primary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING logg@primary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING freq@primary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING pitch@primary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING yaw@primary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING long_an@primary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING irrad_frac_lost_bol@primary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_mode_bol@primary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_func_bol@primary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_coeffs_source_bol@primary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING mass@primary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING requiv_max@secondary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING requiv_min@secondary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING logg@secondary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING freq@secondary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING pitch@secondary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING yaw@secondary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING long_an@secondary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING irrad_frac_lost_bol@secondary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_mode_bol@secondary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_func_bol@secondary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_coeffs_source_bol@secondary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING mass@secondary@star@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_mode@_default@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_coeffs_source@_default@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING intens_weighting@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ebv@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING Av@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING Rv@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING compute_times@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING compute_phases@binary@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING compute_phases_t0@binary@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING pblum_mode@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING pblum_component@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING pblum_dataset@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING pbflux@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING Finite integration Time is not fully supported and will be turned off by legacy wrapper before computation
# Wed, 11 Dec 2019 14:20 IO           WARNING lc_method@lc01@phoebe01@phoebe@compute has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING fti_method@lc01@phoebe01@phoebe@compute has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING fti_oversample@lc01@phoebe01@phoebe@compute has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_mode@primary@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_mode@secondary@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_coeffs_source@primary@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_coeffs_source@secondary@lc01@lc@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING compute_times@rv01@rv@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING intens_weighting@rv01@rv@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ebv@rv01@rv@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING Av@rv01@rv@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING Rv@rv01@rv@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING rv_method@primary@rv01@phoebe01@phoebe@compute has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING rv_grav@primary@rv01@phoebe01@phoebe@compute has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_mode@primary@rv01@rv@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_coeffs_source@primary@rv01@rv@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING rv_method@primary@rv01@legacy01@legacy@compute has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING compute_times@rv01@rv@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING intens_weighting@rv01@rv@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ebv@rv01@rv@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING Av@rv01@rv@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING Rv@rv01@rv@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING rv_method@secondary@rv01@phoebe01@phoebe@compute has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING rv_grav@secondary@rv01@phoebe01@phoebe@compute has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_mode@secondary@rv01@rv@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ld_coeffs_source@secondary@rv01@rv@dataset has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING rv_method@secondary@rv01@legacy01@legacy@compute has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING freq@binary@orbit@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING t0_perpass@binary@orbit@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING t0_supconj@binary@orbit@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING mean_anom@binary@orbit@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING long_an@binary@orbit@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING asini@binary@orbit@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ecosw@binary@orbit@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING esinw@binary@orbit@component has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING irrad_method@legacy01@legacy@compute has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING distortion_method@primary@legacy01@legacy@compute has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING distortion_method@secondary@legacy01@legacy@compute has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING rv_method@primary@rv01@legacy01@legacy@compute has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING rv_method@secondary@rv01@legacy01@legacy@compute has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING t0@system has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING ra@system has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING dec@system has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING distance@system has no phoebe 1 corollary
# Wed, 11 Dec 2019 14:20 IO           WARNING hierarchy@system has no phoebe 1 corollary
# <ParameterSet: 8 parameters | contexts: model, figure>

# %% [markdown]
# Plotting
# -------------------------

# %% [markdown]
# ### Light Curve

# %%
afig, mplfig = b.filter(dataset='lc01').plot(c={'phoebe2model': 'g', 'phoebe1model': 'r'}, linestyle='solid', 
                                             legend=True, show=True)

# %% [markdown]
# Now let's plot the residuals between these two models

# %%
artist, = plt.plot(b.get_value('fluxes@lc01@phoebe2model') - b.get_value('fluxes@lc01@phoebe1model'), 'g-')
artist = plt.axhline(0.0, linestyle='dashed', color='k')

# %% [markdown]
# ### RVs

# %%
afig, mplfig = b['rv01'].plot(c={'phoebe2model': 'g', 'phoebe1model': 'r'}, linestyle='solid', 
                              legend=True, show=True)

# %%
artist, = plt.plot(b.get_value('rvs@primary@phoebe2model', ) - b.get_value('rvs@primary@phoebe1model'), color='g', ls=':')
artist, = plt.plot(b.get_value('rvs@secondary@phoebe2model') - b.get_value('rvs@secondary@phoebe1model'), color='g', ls='-.')
artist = plt.axhline(0.0, linestyle='dashed', color='k')
ylim = plt.ylim(-0.3, 0.3)
